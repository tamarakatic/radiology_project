# %%
import pandas as pd

pd.set_option('max_colwidth', 400)

# %%
df_ft_no_back_parag = pd.read_csv("../results/rouge_test_results_paragraph.csv")
df_ft_no_back_seq = pd.read_csv("../results/rouge_test_results_sequence.csv")

# %%
df_ft_no_back_parag[:10]
# Out:
#                                                                                                                                                                                                                           ground truth  \
# 0                                                                                                                                             calcified granuloma / lung / upper lobe / right . density / cardiophrenic angle / left .
# 1                                                                                                                                 calcified granuloma / lung / lingula . breast implants . deformity / thoracic vertebrae / moderate .
# 2            sutures / lung / apex / right . lung , hyperlucent . lung / hyperdistention . pulmonary emphysema . airspace disease / lung / lower lobe / left . pleural effusion / left / moderate . pleural effusion / right / small .
# ...

# %%
sum(df_ft_no_back_parag.rougeL) / len(df_ft_no_back_parag)
# Out:
# 71.89801214574895

# %%
df_ft_no_back_seq[:10]
# Out:
#                                                                                                                                                                                                                           ground truth  \
# 0                                                                                                                                             calcified granuloma / lung / upper lobe / right . density / cardiophrenic angle / left .
# 1                                                                                                                                 calcified granuloma / lung / lingula . breast implants . deformity / thoracic vertebrae / moderate .
# 2            sutures / lung / apex / right . lung , hyperlucent . lung / hyperdistention . pulmonary emphysema . airspace disease / lung / lower lobe / left . pleural effusion / left / moderate . pleural effusion / right / small .
# ...

# %%
sum(df_ft_no_back_seq.rougeL) / len(df_ft_no_back_seq)
# Out:
# 70.0185060728745
